# %%
import numpy as np
import matplotlib.pyplot as plt

afm1 = np.loadtxt('afm1_radial.dat')
afm2 = np.loadtxt('afm2_radial.dat')

# %%
plt.scatter(afm1[:,0],afm1[:,2]-afm2[:,2])
plt.ylabel('AFM1-AFM2')
# Out:
# Text(0, 0.5, 'AFM1-AFM2')
